# %%
import pandas as pd

# %%
url = "/home/aurelien/code/baptperr/clairvoyance/raw_data/train/_annotations.csv"
labels = pd.DataFrame(pd.read_csv(url))
labels
# Out:
#                                                 filename  width  height  \
# 0      2024-10-23-22-51-03_mp4-0507_jpg.rf.f9ff7fca1c...    640     640
# 1      2024-10-23-22-51-03_mp4-0507_jpg.rf.f9ff7fca1c...    640     640
# 2      2024-10-23-22-51-03_mp4-0507_jpg.rf.f9ff7fca1c...    640     640
# 3      2024-10-23-22-51-03_mp4-0507_jpg.rf.f9ff7fca1c...    640     640
# 4      2024-11-21-09-14-17_mp4-0094_jpg.rf.bbe2c785f9...    640     640
# ...                                                  ...    ...     ...
# 93024  2024-10-22-20-37-02_mp4-0926_jpg.rf.612b6e3725...    640     640
# 93025  2024-10-22-20-37-02_mp4-0926_jpg.rf.612b6e3725...    640     640
# 93026  2024-10-22-20-37-02_mp4-0926_jpg.rf.612b6e3725...    640     640
# 93027  2024-10-22-20-37-02_mp4-0926_jpg.rf.612b6e3725...    640     640
# 93028  2024-10-22-20-37-02_mp4-0926_jpg.rf.612b6e3725...    640     640
#
#             class  xmin  ymin  xmax  ymax
# 0             car     0   337   128   442
# ...
